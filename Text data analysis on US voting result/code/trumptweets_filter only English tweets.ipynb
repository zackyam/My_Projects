# %%
import numpy as np
import pandas as pd
import spacy
import re
import pycld2 as cld2
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as snb
from wordcloud import WordCloud, STOPWORDS
import math
from scipy.stats import chi2_contingency, chisquare, chi2
import nltk  
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.probability import FreqDist
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from textblob import TextBlob
from textblob import Word

# %%
def clean_tweet(tweet):
    tweet = tweet.lower()
    tweet = re.sub(r"@[A-Za-z0-9]+","", tweet)
    tweet = re.sub(r"#","", tweet)
    tweet = re.sub(r"\ART[\s]+","", tweet) 
    tweet = re.sub(r"https?:\/\/\S+","", tweet)
    tweet = re.sub("(.)\\1{2,}","\\1", tweet)
    tweet = re.sub(r"[^A-Za-z0-9\s]+", "",str(tweet))
    
    return tweet

# %%
trump_df = pd.read_csv('hashtag_joebiden.csv', lineterminator='\n')

# %%
trump_df.head(5)
# Out:
#             created_at      tweet_id  \
# 0  2020-10-15 00:00:01  1.316529e+18
# 1  2020-10-15 00:00:18  1.316529e+18
# 2  2020-10-15 00:00:20  1.316529e+18
# 3  2020-10-15 00:00:21  1.316529e+18
# 4  2020-10-15 00:00:22  1.316529e+18
#
#                                                tweet  likes  retweet_count  \
# 0  #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0            0.0
# 1  #HunterBiden #HunterBidenEmails #JoeBiden #Joe...    0.0            0.0
# 2  @IslandGirlPRV @BradBeauregardJ @MeidasTouch T...    0.0            0.0
# 3  @chrislongview Watching and setting dvr. Let’s...    0.0            0.0
# 4  #censorship #HunterBiden #Biden #BidenEmails #...    1.0            0.0
#
#                source       user_id           user_name user_screen_name  \
# 0           TweetDeck  3.606665e+08  El Sol Latino News  elsollatinonews
# 1    Twitter for iPad  8.099044e+08         Cheri A. 🇺🇸     Biloximeemaw
# 2     Twitter Web App  3.494182e+09          Flag Waver      Flag_Wavers
# 3  Twitter for iPhone  8.242596e+17       Michelle Ferg    MichelleFerg4
# 4     Twitter Web App  1.032807e+18      the Gold State    theegoldstate
#
#                                     user_description  ...  \
# 0  🌐 Noticias de interés para latinos de la costa...  ...
# 1  Locked and loaded Meemaw. Love God, my family ...  ...
# 2                                                NaN  ...
# 3                                                NaN  ...
# 4  A Silicon Valley #independent #News #Media #St...  ...
#
#   user_followers_count                 user_location        lat        long  \
# 0               1860.0  Philadelphia, PA / Miami, FL  25.774270  -80.193660
# 1               6628.0                           NaN        NaN         NaN
# 2               1536.0         Golden Valley Arizona  46.304036 -109.171431
# 3                 27.0                           NaN        NaN         NaN
# 4                390.0               California, USA  36.701463 -118.755997
#
#    city                   country      continent       state state_code  \
# 0   NaN  United States of America  North America     Florida         FL
# 1   NaN                       NaN            NaN         NaN        NaN
# 2   NaN  United States of America  North America     Montana         MT
# 3   NaN                       NaN            NaN         NaN        NaN
# 4   NaN  United States of America  North America  California         CA
#
#                     collected_at
# 0            2020-10-21 00:00:00
# 1  2020-10-21 00:00:00.517827283
# 2  2020-10-21 00:00:01.035654566
# 3  2020-10-21 00:00:01.553481849
# 4  2020-10-21 00:00:02.071309132
#
# [5 rows x 21 columns]

# %%
trump_df["tweet"] = trump_df["tweet"].apply(clean_tweet)

# %%
trump_df["tweet"]
# Out:
# 0         elecciones2020  en florida joebiden dice que d...
# 1         hunterbiden hunterbidenemails joebiden joebide...
# 2          this is how biden made his  trumpisnotamerica \n
# 3          watching and setting dvr lets give him bonus ...
# 4         censorship hunterbiden biden bidenemails biden...
#                                 ...
# 776881    stop laying  \nparis and london dont give a fu...
# 776882                                               biden
# 776883    lotan va sortir de sa lthargie et redevenir le...
# 776884    \n\ncongiuntifuoriregione\n\nsono felice per j...
# 776885    ik moet zeggen dat ik biden the lesser of two ...
# Name: tweet, Length: 776886, dtype: object

# %%
trump_tweet = trump_df.drop(columns=['tweet_id','user_id','user_name','user_screen_name',
                                  'user_description','user_join_date','collected_at'])

# %%
def detect_lang(tweet):
    try:
        isReliable, textBytesFound, details = cld2.detect(tweet)
        return details[0][0]
    except:
        return "not found"

# %%
train_langs = trump_tweet["tweet"].apply(detect_lang)

# %%
trump_tweet["lang"] = train_langs

# %%
trump_tweet_train = trump_tweet[trump_tweet["lang"] == "ENGLISH"]

# %%
len(trump_tweet_train)
# Out:
# 526887

# %%
trump_tweet_train.head(5)
# Out:
#             created_at                                              tweet  \
# 2  2020-10-15 00:00:20   this is how biden made his  trumpisnotamerica \n
# 3  2020-10-15 00:00:21   watching and setting dvr lets give him bonus ...
# 4  2020-10-15 00:00:22  censorship hunterbiden biden bidenemails biden...
# 5  2020-10-15 00:00:23  is this wrong cory bookers brilliant final que...
# 6  2020-10-15 00:00:25  in 2020 nypost is being censorship censored by...
#
#    likes  retweet_count              source  user_followers_count  \
# 2    0.0            0.0     Twitter Web App                1536.0
# 3    0.0            0.0  Twitter for iPhone                  27.0
# 4    1.0            0.0     Twitter Web App                 390.0
# 5    0.0            0.0     Twitter Web App                4622.0
# 6    0.0            0.0  Twitter for iPhone                1397.0
#
#            user_location        lat        long     city  \
# 2  Golden Valley Arizona  46.304036 -109.171431      NaN
# 3                    NaN        NaN         NaN      NaN
# 4        California, USA  36.701463 -118.755997      NaN
# 5                    NaN        NaN         NaN      NaN
# 6      Chicago, Illinois  41.875562  -87.624421  Chicago
#
#                     country      continent       state state_code     lang
# 2  United States of America  North America     Montana         MT  ENGLISH
# 3                       NaN            NaN         NaN        NaN  ENGLISH
# 4  United States of America  North America  California         CA  ENGLISH
# 5                       NaN            NaN         NaN        NaN  ENGLISH
# 6  United States of America  North America    Illinois         IL  ENGLISH

# %%
stop_words = set(stopwords.words('english'))
wordcloud = WordCloud(width=5000, height=4000,stopwords=stop_words,random_state = 2016).generate(" ".join([i for i in trump_tweet_train['tweet'].str.upper()]))
plt.imshow(wordcloud)
plt.axis("off")
plt.title("Joe Tweets Word Cloud")
# Out:
# Text(0.5, 1.0, 'Joe Tweets Word Cloud')

# %%
def lemm_tweet(tweet, stem=False, lemmatize=False):
    temp_tweet = []
    words = word_tokenize(tweet) 

    # Remove stopwords and stem
    for word in words:
        if not word in stop_words:
            if stem:
                temp_tweet.append(ps.stem(word))
            elif lemmatize:
                temp_tweet.append(Word(word).lemmatize())
            else:
                temp_tweet.append(word)
                
    return temp_tweet

# %%
trump_tweet_train.tweet = trump_tweet_train.tweet.apply(lambda x: lemm_tweet(x))
# Out:
# C:\Users\Zack\anaconda3\lib\site-packages\pandas\core\generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
def sentiment_analysis(df):
    
    # Determine polarity and subjectivity
    df['Polarity'] = df['tweet'].apply(lambda x: TextBlob(' '.join(x)).sentiment.polarity)
    df['Subjectivity'] = df['tweet'].apply(lambda x: TextBlob(' '.join(x)).sentiment.subjectivity)
    
    # Classify overall sentiment
    df.loc[df.Polarity > 0,'Sentiment'] = 1
    df.loc[df.Polarity == 0,'Sentiment'] = 0
    df.loc[df.Polarity < 0,'Sentiment'] = -1
    
    return df

# %%
sentiment_analysis(trump_tweet_train)
# Out:
# <ipython-input-45-723e8472946e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['tweet'].apply(lambda x: TextBlob(' '.join(x)).sentiment.polarity)
# <ipython-input-45-723e8472946e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Subjectivity'] = df['tweet'].apply(lambda x: TextBlob(' '.join(x)).sentiment.subjectivity)
# C:\Users\Zack\anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\Zack\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Zack\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Zack\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#                  created_at  \
# 2       2020-10-15 00:00:20
# 3       2020-10-15 00:00:21
# 4       2020-10-15 00:00:22
# 5       2020-10-15 00:00:23
# 6       2020-10-15 00:00:25
# ...                     ...
# 776874  2020-11-08 23:59:06
# 776876  2020-11-08 23:59:16
# 776877  2020-11-08 23:59:32
# 776878  2020-11-08 23:59:33
# 776881  2020-11-08 23:59:38
#
#                                                     tweet  likes  \
# 2                        [biden, made, trumpisnotamerica]    0.0
# 3       [watching, setting, dvr, lets, give, bonus, ra...    0.0
# 4       [censorship, hunterbiden, biden, bidenemails, ...    1.0
# 5       [wrong, cory, bookers, brilliant, final, quest...    0.0
# 6       [2020, nypost, censorship, censored, twitter, ...    0.0
# ...                                                   ...    ...
# 776874  [biden, camps, announcement, idlib, merely, ai...    1.0
# 776876  [mr, biden, tear, wall, mexico, whats, never, ...    1.0
# 776877  [nyt, beratalbayraks, departure, may, also, si...    3.0
# 776878  [thank, support, hard, work, biden, harris, ti...    2.0
# 776881  [stop, laying, paris, london, dont, give, fuck...    0.0
#
#         retweet_count               source  user_followers_count  \
# 2                 0.0      Twitter Web App                1536.0
# 3                 0.0   Twitter for iPhone                  27.0
# 4                 0.0      Twitter Web App                 390.0
# 5                 0.0      Twitter Web App                4622.0
# 6                 0.0   Twitter for iPhone                1397.0
# ...               ...                  ...                   ...
# 776874            0.0      Twitter Web App                3019.0
# 776876            0.0   Twitter for iPhone                 444.0
# 776877            0.0   Twitter for iPhone               14770.0
# 776878            1.0  Twitter for Android                  52.0
# 776881            0.0   Twitter for iPhone                  27.0
#
#                          user_location        lat        long      city  \
# 2                Golden Valley Arizona  46.304036 -109.171431       NaN
# 3                                  NaN        NaN         NaN       NaN
# 4                      California, USA  36.701463 -118.755997       NaN
# 5                                  NaN        NaN         NaN       NaN
# 6                    Chicago, Illinois  41.875562  -87.624421   Chicago
# ...                                ...        ...         ...       ...
# 776874                             NaN        NaN         NaN       NaN
# 776876                    Auckland, NZ -36.852095  174.763180  Auckland
# 776877  London/ Istanbul/Izmir /Beirut        NaN         NaN       NaN
# 776878                             NaN        NaN         NaN       NaN
# 776881                           PARIS  48.856697    2.351462     Paris
#
#                          country      continent          state state_code  \
# 2       United States of America  North America        Montana         MT
# 3                            NaN            NaN            NaN        NaN
# 4       United States of America  North America     California         CA
# 5                            NaN            NaN            NaN        NaN
# 6       United States of America  North America       Illinois         IL
# ...                          ...            ...            ...        ...
# 776874                       NaN            NaN            NaN        NaN
# 776876               New Zealand        Oceania       Auckland        AUK
# 776877                       NaN            NaN            NaN        NaN
# 776878                       NaN            NaN            NaN        NaN
# 776881                    France         Europe  Ile-de-France        IDF
#
#            lang  Polarity  Subjectivity  Sentiment
# 2       ENGLISH  0.000000      0.000000        0.0
# 3       ENGLISH  0.000000      0.000000        0.0
# 4       ENGLISH  0.000000      0.000000        0.0
# 5       ENGLISH  0.133333      0.966667        1.0
# 6       ENGLISH -0.148810      0.678571       -1.0
# ...         ...       ...           ...        ...
# 776874  ENGLISH -0.500000      0.500000       -1.0
# 776876  ENGLISH  0.311111      0.611111        1.0
# 776877  ENGLISH  0.000000      0.000000        0.0
# 776878  ENGLISH -0.291667      0.541667       -1.0
# 776881  ENGLISH -0.400000      0.600000       -1.0
#
# [526887 rows x 18 columns]

# %%
trump_tweet_train.to_csv('joe_tweet_senti.csv', index = False)

# %%
predictions

# %%
trump_tweet_train["Polarity"].mean()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(train_data, targets, test_size=0.33)
model.fit(X_train, Y_train)

# %%
def check_model_metrics(model, test_data, test_targets):
    y_pred = model.predict(test_data)

    print("ACCURACY:")
    print(metrics.accuracy_score(test_targets, y_pred)*100)

    print("\nCONFUSSION MATRIX")
    print(confusion_matrix(test_targets, y_pred))

    print("\nCLASSIFICATION REPORT")
    print(classification_report(test_targets, y_pred))

# %%
train_data = trump_tweet_train['tweet']

# %%
targets = trump_tweet_train["Sentiment"]

# %%
model, x_test, y_test = train_model(train_data, targets)

# %%
trump_tweet_train
