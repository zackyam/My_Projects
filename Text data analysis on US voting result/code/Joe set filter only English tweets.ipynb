# %%
import numpy as np
import pandas as pd
import spacy
import re
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as snb
from wordcloud import WordCloud, STOPWORDS
import math
from scipy.stats import chi2_contingency, chisquare, chi2
import nltk  
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.probability import FreqDist
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.model_selection import GridSearchCV
import tensorflow as tf
import pycld2 as cld2
from textblob import TextBlob
from textblob import Word

# %%
def clean_tweet_text_regex(tweet):
    tweet = tweet.lower() # to lower case
    tweet = re.sub(r"@[A-Za-z0-9]+","", tweet) # Remove @Mentions
    tweet = re.sub(r"#","", tweet) # remove # \ART[\s]+
    tweet = re.sub(r"\ART[\s]+","", tweet) # Remove RT in start
    tweet = re.sub(r"https?:\/\/\S+","", tweet) # Remove hyperlink
    tweet = re.sub("(.)\\1{2,}","\\1", tweet) # Remove more than one characters.
    tweet = re.sub(r"[^A-Za-z0-9\s]+", "",str(tweet)) #remove special characters "!"
    
    return tweet

# %%
def detect_lang(tweet):
    try:
        isReliable, textBytesFound, details = cld2.detect(tweet)
        return details[0][0]
    except:
        return "not found"

# %%
joe_df = pd.read_csv('hashtag_joebiden.csv', lineterminator='\n')

# %%
joe_df["tweetNew"] = joe_df["tweet"].apply(clean_tweet_text_regex)

# %%
train_langs = joe_df["tweetNew"].apply(detect_lang)

# %%
train_langs.value_counts()
# Out:
# ENGLISH       526887
# Unknown       118878
# SPANISH        32578
# FRENCH         22488
# GERMAN         19271
#                ...
# FIJIAN             1
# NYANJA             1
# VIETNAMESE         1
# SUNDANESE          1
# FAROESE            1
# Name: tweetNew, Length: 100, dtype: int64

# %%
joe_df["Lang"] = train_langs

# %%
joe_df_ng = joe_df.loc[joe_df['Lang'] == "ENGLISH"]

# %%
joe_df_ng
# Out:
#                  created_at      tweet_id  \
# 2       2020-10-15 00:00:20  1.316529e+18
# 3       2020-10-15 00:00:21  1.316529e+18
# 4       2020-10-15 00:00:22  1.316529e+18
# 5       2020-10-15 00:00:23  1.316529e+18
# 6       2020-10-15 00:00:25  1.316529e+18
# ...                     ...           ...
# 776874  2020-11-08 23:59:06  1.325589e+18
# 776876  2020-11-08 23:59:16  1.325589e+18
# 776877  2020-11-08 23:59:32  1.325589e+18
# 776878  2020-11-08 23:59:33  1.325589e+18
# 776881  2020-11-08 23:59:38  1.325589e+18
#
#                                                     tweet  likes  \
# 2       @IslandGirlPRV @BradBeauregardJ @MeidasTouch T...    0.0
# 3       @chrislongview Watching and setting dvr. Let’s...    0.0
# 4       #censorship #HunterBiden #Biden #BidenEmails #...    1.0
# 5       "IS THIS WRONG??!!" Cory Booker's BRILLIANT Fi...    0.0
# 6       In 2020, #NYPost is being #censorship #CENSORE...    0.0
# ...                                                   ...    ...
# 776874  @SamRamani2 #Biden camps announcement on Idlib...    1.0
# 776876  Mr. #Biden, tear down that wall (with #Mexico)...    1.0
# 776877  NYT: #BeratAlbayrak’s departure may also signa...    3.0
# 776878  @staceyabrams Thank you for all your support a...    2.0
# 776881  Stop laying @CNN !\n#Paris and #London dont gi...    0.0
#
#         retweet_count               source       user_id  \
# 2                 0.0      Twitter Web App  3.494182e+09
# 3                 0.0   Twitter for iPhone  8.242596e+17
# 4                 0.0      Twitter Web App  1.032807e+18
# 5                 0.0      Twitter Web App  3.057279e+08
# 6                 0.0   Twitter for iPhone  1.994033e+07
# ...               ...                  ...           ...
# 776874            0.0      Twitter Web App  8.169274e+17
# 776876            0.0   Twitter for iPhone  3.772296e+08
# 776877            0.0   Twitter for iPhone  2.646308e+07
# 776878            1.0  Twitter for Android  2.252249e+08
# 776881            0.0   Twitter for iPhone  3.873620e+08
#
#                                                 user_name user_screen_name  \
# 2                                              Flag Waver      Flag_Wavers
# 3                                           Michelle Ferg    MichelleFerg4
# 4                                          the Gold State    theegoldstate
# 5                                      Dose of Dissonance  Dose_Dissonance
# 6       Change Illinois | Biden will increase taxes by...   changeillinois
# ...                                                   ...              ...
# 776874                                     TurkishFacts4u   TurkishFacts4U
# 776876                                          Tim Welch        TimFWelch
# 776877                                 Cagil M. Kasapoglu   CagilKasapoglu
# 776878           #BidenHarris2020 Amen, God Bless America          tabup23
# 776881                                            flaquet         flaquet1
#
#                                          user_description  ...        lat  \
# 2                                                     NaN  ...  46.304036
# 3                                                     NaN  ...        NaN
# 4       A Silicon Valley #independent #News #Media #St...  ...  36.701463
# 5       YOUTUBE CHANNEL: https://t.co/EFnKm5gnvV MERCH...  ...        NaN
# 6       Illinois, home of Lincoln and Reagan, used to ...  ...  41.875562
# ...                                                   ...  ...        ...
# 776874  ᴄᴏᴜɴᴛᴇʀɪɴɢ ᴘᴇʀᴄᴇᴘᴛɪᴏɴ ᴍᴀɴᴀɢᴇᴍᴇɴᴛ ᴄᴀᴍᴘᴀɪɢɴꜱ ᴀɢᴀ...  ...        NaN
# 776876  transportation nerd; data geek.\nsenior lectur...  ... -36.852095
# 776877  Journalist | BBC WS | @bbcturkce | Eyes on 🌍 |...  ...        NaN
# 776878                                                NaN  ...        NaN
# 776881                                                NaN  ...  48.856697
#
#               long      city                   country      continent  \
# 2      -109.171431       NaN  United States of America  North America
# 3              NaN       NaN                       NaN            NaN
# 4      -118.755997       NaN  United States of America  North America
# 5              NaN       NaN                       NaN            NaN
# 6       -87.624421   Chicago  United States of America  North America
# ...            ...       ...                       ...            ...
# 776874         NaN       NaN                       NaN            NaN
# 776876  174.763180  Auckland               New Zealand        Oceania
# 776877         NaN       NaN                       NaN            NaN
# 776878         NaN       NaN                       NaN            NaN
# 776881    2.351462     Paris                    France         Europe
#
#                 state state_code                   collected_at  \
# 2             Montana         MT  2020-10-21 00:00:01.035654566
# 3                 NaN        NaN  2020-10-21 00:00:01.553481849
# 4          California         CA  2020-10-21 00:00:02.071309132
# 5                 NaN        NaN  2020-10-21 00:00:02.589136415
# 6            Illinois         IL  2020-10-21 00:00:03.106963698
# ...               ...        ...                            ...
# 776874            NaN        NaN     2020-11-09 18:32:45.811602
# 776876       Auckland        AUK     2020-11-09 18:32:45.760347
# 776877            NaN        NaN     2020-11-09 18:32:45.595167
# 776878            NaN        NaN     2020-11-09 18:32:45.880153
# 776881  Ile-de-France        IDF     2020-11-09 18:32:45.613547
#
#                                                  tweetNew     Lang
# 2        this is how biden made his  trumpisnotamerica \n  ENGLISH
# 3        watching and setting dvr lets give him bonus ...  ENGLISH
# 4       censorship hunterbiden biden bidenemails biden...  ENGLISH
# 5       is this wrong cory bookers brilliant final que...  ENGLISH
# 6       in 2020 nypost is being censorship censored by...  ENGLISH
# ...                                                   ...      ...
# 776874   biden camps announcement on idlib is merely a...  ENGLISH
# 776876  mr biden tear down that wall with mexico\nwhat...  ENGLISH
# 776877  nyt beratalbayraks departure may also signal a...  ENGLISH
# 776878   thank you for all your support and hard work ...  ENGLISH
# 776881  stop laying  \nparis and london dont give a fu...  ENGLISH
#
# [526887 rows x 23 columns]

# %%
to_remove = r'\d+|http?\S+|[^A-Za-z0-9]+'
stop_words = set(stopwords.words('english'))
ps = PorterStemmer()

# Function to preprocess tweet 
def clean_tweet(tweet, stem=False, lemmatize=False):
        
    filtered_tweet = []
    words = word_tokenize(tweet) 

    # Remove stopwords and stem
    for word in words:
        if not word in stop_words:
            if stem:
                filtered_tweet.append(ps.stem(word))
            elif lemmatize:
                filtered_tweet.append(Word(word).lemmatize())
            else:
                filtered_tweet.append(word)
            
    return filtered_tweet

# %%
joe_df_ng['tweetNew'] = joe_df_ng.tweetNew.apply(lambda x: clean_tweet(x))
# Out:
# <ipython-input-29-868efd646d7c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joe_df_ng['tweetNew'] = joe_df_ng.tweetNew.apply(lambda x: clean_tweet(x))

# %%
def sentiment_analysis(df):
    
    # Determine polarity and subjectivity
    df['Polarity'] = df['tweetNew'].apply(lambda x: TextBlob(' '.join(x)).sentiment.polarity)
    df['Subjectivity'] = df['tweetNew'].apply(lambda x: TextBlob(' '.join(x)).sentiment.subjectivity)
    
    # Classify overall sentiment
    df.loc[df.Polarity > 0,'Sentiment'] = 1
    df.loc[df.Polarity == 0,'Sentiment'] = 0
    df.loc[df.Polarity < 0,'Sentiment'] = -1
    
    return df

# %%
joe_tweet_senti = sentiment_analysis(joe_df_ng)
# Out:
# <ipython-input-30-0239adf32aa3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['tweetNew'].apply(lambda x: TextBlob(' '.join(x)).sentiment.polarity)
# <ipython-input-30-0239adf32aa3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Subjectivity'] = df['tweetNew'].apply(lambda x: TextBlob(' '.join(x)).sentiment.subjectivity)
# C:\Users\Zack\anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\Zack\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Zack\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Zack\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
joe_tweet_senti
# Out:
#                  created_at      tweet_id  \
# 2       2020-10-15 00:00:20  1.316529e+18
# 3       2020-10-15 00:00:21  1.316529e+18
# 4       2020-10-15 00:00:22  1.316529e+18
# 5       2020-10-15 00:00:23  1.316529e+18
# 6       2020-10-15 00:00:25  1.316529e+18
# ...                     ...           ...
# 776874  2020-11-08 23:59:06  1.325589e+18
# 776876  2020-11-08 23:59:16  1.325589e+18
# 776877  2020-11-08 23:59:32  1.325589e+18
# 776878  2020-11-08 23:59:33  1.325589e+18
# 776881  2020-11-08 23:59:38  1.325589e+18
#
#                                                     tweet  likes  \
# 2       @IslandGirlPRV @BradBeauregardJ @MeidasTouch T...    0.0
# 3       @chrislongview Watching and setting dvr. Let’s...    0.0
# 4       #censorship #HunterBiden #Biden #BidenEmails #...    1.0
# 5       "IS THIS WRONG??!!" Cory Booker's BRILLIANT Fi...    0.0
# 6       In 2020, #NYPost is being #censorship #CENSORE...    0.0
# ...                                                   ...    ...
# 776874  @SamRamani2 #Biden camps announcement on Idlib...    1.0
# 776876  Mr. #Biden, tear down that wall (with #Mexico)...    1.0
# 776877  NYT: #BeratAlbayrak’s departure may also signa...    3.0
# 776878  @staceyabrams Thank you for all your support a...    2.0
# 776881  Stop laying @CNN !\n#Paris and #London dont gi...    0.0
#
#         retweet_count               source       user_id  \
# 2                 0.0      Twitter Web App  3.494182e+09
# 3                 0.0   Twitter for iPhone  8.242596e+17
# 4                 0.0      Twitter Web App  1.032807e+18
# 5                 0.0      Twitter Web App  3.057279e+08
# 6                 0.0   Twitter for iPhone  1.994033e+07
# ...               ...                  ...           ...
# 776874            0.0      Twitter Web App  8.169274e+17
# 776876            0.0   Twitter for iPhone  3.772296e+08
# 776877            0.0   Twitter for iPhone  2.646308e+07
# 776878            1.0  Twitter for Android  2.252249e+08
# 776881            0.0   Twitter for iPhone  3.873620e+08
#
#                                                 user_name user_screen_name  \
# 2                                              Flag Waver      Flag_Wavers
# 3                                           Michelle Ferg    MichelleFerg4
# 4                                          the Gold State    theegoldstate
# 5                                      Dose of Dissonance  Dose_Dissonance
# 6       Change Illinois | Biden will increase taxes by...   changeillinois
# ...                                                   ...              ...
# 776874                                     TurkishFacts4u   TurkishFacts4U
# 776876                                          Tim Welch        TimFWelch
# 776877                                 Cagil M. Kasapoglu   CagilKasapoglu
# 776878           #BidenHarris2020 Amen, God Bless America          tabup23
# 776881                                            flaquet         flaquet1
#
#                                          user_description  ...  \
# 2                                                     NaN  ...
# 3                                                     NaN  ...
# 4       A Silicon Valley #independent #News #Media #St...  ...
# 5       YOUTUBE CHANNEL: https://t.co/EFnKm5gnvV MERCH...  ...
# 6       Illinois, home of Lincoln and Reagan, used to ...  ...
# ...                                                   ...  ...
# 776874  ᴄᴏᴜɴᴛᴇʀɪɴɢ ᴘᴇʀᴄᴇᴘᴛɪᴏɴ ᴍᴀɴᴀɢᴇᴍᴇɴᴛ ᴄᴀᴍᴘᴀɪɢɴꜱ ᴀɢᴀ...  ...
# 776876  transportation nerd; data geek.\nsenior lectur...  ...
# 776877  Journalist | BBC WS | @bbcturkce | Eyes on 🌍 |...  ...
# 776878                                                NaN  ...
# 776881                                                NaN  ...
#
#                          country      continent          state  state_code  \
# 2       United States of America  North America        Montana          MT
# 3                            NaN            NaN            NaN         NaN
# 4       United States of America  North America     California          CA
# 5                            NaN            NaN            NaN         NaN
# 6       United States of America  North America       Illinois          IL
# ...                          ...            ...            ...         ...
# 776874                       NaN            NaN            NaN         NaN
# 776876               New Zealand        Oceania       Auckland         AUK
# 776877                       NaN            NaN            NaN         NaN
# 776878                       NaN            NaN            NaN         NaN
# 776881                    France         Europe  Ile-de-France         IDF
#
#                          collected_at  \
# 2       2020-10-21 00:00:01.035654566
# 3       2020-10-21 00:00:01.553481849
# 4       2020-10-21 00:00:02.071309132
# 5       2020-10-21 00:00:02.589136415
# 6       2020-10-21 00:00:03.106963698
# ...                               ...
# 776874     2020-11-09 18:32:45.811602
# 776876     2020-11-09 18:32:45.760347
# 776877     2020-11-09 18:32:45.595167
# 776878     2020-11-09 18:32:45.880153
# 776881     2020-11-09 18:32:45.613547
#
#                                                  tweetNew     Lang  Polarity  \
# 2                        [biden, made, trumpisnotamerica]  ENGLISH  0.000000
# 3       [watching, setting, dvr, lets, give, bonus, ra...  ENGLISH  0.000000
# 4       [censorship, hunterbiden, biden, bidenemails, ...  ENGLISH  0.000000
# 5       [wrong, cory, bookers, brilliant, final, quest...  ENGLISH  0.133333
# 6       [2020, nypost, censorship, censored, twitter, ...  ENGLISH -0.148810
# ...                                                   ...      ...       ...
# 776874  [biden, camps, announcement, idlib, merely, ai...  ENGLISH -0.500000
# 776876  [mr, biden, tear, wall, mexico, whats, never, ...  ENGLISH  0.311111
# 776877  [nyt, beratalbayraks, departure, may, also, si...  ENGLISH  0.000000
# 776878  [thank, support, hard, work, biden, harris, ti...  ENGLISH -0.291667
# 776881  [stop, laying, paris, london, dont, give, fuck...  ENGLISH -0.400000
#
#        Subjectivity Sentiment
# 2          0.000000       0.0
# 3          0.000000       0.0
# 4          0.000000       0.0
# 5          0.966667       1.0
# 6          0.678571      -1.0
# ...             ...       ...
# 776874     0.500000      -1.0
# 776876     0.611111       1.0
# 776877     0.000000       0.0
# 776878     0.541667      -1.0
# 776881     0.600000      -1.0
#
# [526887 rows x 26 columns]
