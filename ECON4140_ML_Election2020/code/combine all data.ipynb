# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.svm import SVC
import statsmodels.api as sm
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
election_result = pd.read_csv("election_result.csv")

# %%
election_result = election_result.rename(columns={'county_fips': 'FIPS Code'})

# %%
election_result
# Out:
#       FIPS Code  Rep2020  Rep2016
# 0          1001        1        1
# 1          1003        1        1
# 2          1005        1        1
# 3          1007        1        1
# 4          1009        1        1
# ...         ...      ...      ...
# 3106      56037        1        1
# 3107      56039        0        0
# 3108      56041        1        1
# 3109      56043        1        1
# 3110      56045        1        1
#
# [3111 rows x 3 columns]

# %%
Education = pd.read_csv("Education.csv")

# %%
Education = Education.drop(["State","Area name"], axis=1)

# %%
PopulationEstimates = pd.read_csv("PopulationEstimates.csv")

# %%
PopulationEstimates = PopulationEstimates.drop(["State","Area_Name"], axis=1)

# %%
PopulationEstimates = PopulationEstimates.rename(columns={'FIPStxt': 'FIPS Code'})

# %%
PovertyEstimates = pd.read_csv("PovertyEstimates.csv")

# %%
PovertyEstimates = PovertyEstimates.drop(["Stabr","Area_name"], axis=1)
PovertyEstimates = PovertyEstimates.rename(columns={'FIPStxt': 'FIPS Code'})

# %%
Unemployment = pd.read_csv("Unemployment.csv")

# %%
Unemployment = Unemployment.drop(["Stabr","area_name"], axis=1)
Unemployment = Unemployment.rename(columns={'fips_txt': 'FIPS Code'})

# %%
Unemployment
# Out:
#       FIPS Code Civilian_labor_force_2019 Employed_2019 Unemployed_2019  \
# 0             0               163,100,055   157,115,247       5,984,808
# 1          1000                 2,241,747     2,174,483          67,264
# 2          1001                    26,172        25,458             714
# 3          1003                    97,328        94,675           2,653
# 4          1005                     8,537         8,213             324
# ...         ...                       ...           ...             ...
# 3270      72145                    13,037        11,791           1,246
# 3271      72147                     2,585         2,406             179
# 3272      72149                     7,406         6,231           1,175
# 3273      72151                     8,691         7,552           1,139
# 3274      72153                     9,759         8,331           1,428
#
#       Unemployment_rate_2019 Median_Household_Income_2019  \
# ...

# %%
df = Education.merge(PopulationEstimates, on='FIPS Code', how='inner', suffixes=('_1', '_2'))

# %%
df = df.merge(PovertyEstimates, on='FIPS Code', how='inner', suffixes=('_1', '_2'))

# %%
df = df.merge(Unemployment, on='FIPS Code', how='inner', suffixes=('_1', '_2'))

# %%
df
# Out:
#       FIPS Code Less than a high school diploma, 2015-19  \
# 0             0                               26,472,261
# 1          1000                                  458,922
# 2          1001                                    4,291
# 3          1003                                   13,893
# 4          1005                                    4,812
# ...         ...                                      ...
# 3188      56037                                    2,017
# 3189      56039                                      834
# 3190      56041                                      941
# 3191      56043                                      568
# 3192      56045                                      323
#
#      High school diploma only, 2015-19  \
# 0                           59,472,748
# 1                            1,022,839
# 2                               12,551
# 3                               41,797
# 4                                6,396
# ...

# %%
final_df = election_result.merge(df, on='FIPS Code', how='inner', suffixes=('_1', '_2'))

# %%
final_df
# Out:
#       FIPS Code  Rep2020  Rep2016 Less than a high school diploma, 2015-19  \
# 0          1001        1        1                                    4,291
# 1          1003        1        1                                   13,893
# 2          1005        1        1                                    4,812
# 3          1007        1        1                                    3,386
# 4          1009        1        1                                    7,763
# ...         ...      ...      ...                                      ...
# 3106      56037        1        1                                    2,017
# 3107      56039        0        0                                      834
# 3108      56041        1        1                                      941
# 3109      56043        1        1                                      568
# 3110      56045        1        1                                      323
#
#      High school diploma only, 2015-19  \
# ...

# %%
final_df.to_csv("final_df.csv",index=False)
